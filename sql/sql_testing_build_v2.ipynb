# %%
import sqlite3
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
connection = sqlite3.connect('../dbs/bronze.db') 
connection.cursor().execute('DROP TABLE competitions')
connection.cursor().execute('DROP TABLE matches')

# %%
connection = sqlite3.connect('../dbs/silver.db')

# 2. Read query directly into a DataFrame
df = pd.read_sql_query('SELECT COUNT(*) FROM events', connection)

# 3. Always close the connection when finished
connection.close()

df
# Out:
#    COUNT(*)
# 0    234637

# %%
connection = sqlite3.connect('../dbs/bronze.db')

# 2. Read query directly into a DataFrame
df = pd.read_sql_query('SELECT * FROM events WHERE id = "001b722a-126d-4e94-a20b-55ccfc3f45d8"', connection)

# 3. Always close the connection when finished
connection.close()

df
# Out:
#                                      id  period     timestamp  minute  second  \
# 0  001b722a-126d-4e94-a20b-55ccfc3f45d8       1  00:03:36.020       3      36
# 1  001b722a-126d-4e94-a20b-55ccfc3f45d8       1  00:03:36.020       3      36
# 2  001b722a-126d-4e94-a20b-55ccfc3f45d8       1  00:03:36.020       3      36
# 3  001b722a-126d-4e94-a20b-55ccfc3f45d8       1  00:03:36.020       3      36
# 4  001b722a-126d-4e94-a20b-55ccfc3f45d8       1  00:03:36.020       3      36
#
#     type  possession possession_team    play_pattern     team  team_id  \
# 0  Carry           8         Ecuador  From Goal Kick  Senegal      787
# 1  Carry           8         Ecuador  From Goal Kick  Senegal      787
# 2  Carry           8         Ecuador  From Goal Kick  Senegal      787
# 3  Carry           8         Ecuador  From Goal Kick  Senegal      787
# 4  Carry           8         Ecuador  From Goal Kick  Senegal      787
#
#               player  player_id                  position tactics  \
# 0  Pathé Ismaël Ciss      31751  Right Defensive Midfield    null
# 1  Pathé Ismaël Ciss      31751  Right Defensive Midfield    null
# 2  Pathé Ismaël Ciss      31751  Right Defensive Midfield    null
# 3  Pathé Ismaël Ciss      31751  Right Defensive Midfield    null
# 4  Pathé Ismaël Ciss      31751  Right Defensive Midfield    null
#
#        location  duration  under_pressure off_camera   out counterpress  \
# 0  [36.7, 24.5]  2.618976               1       None  None         None
# 1  [36.7, 24.5]  2.618976               1       None  None         None
# 2  [36.7, 24.5]  2.618976               1       None  None         None
# 3  [36.7, 24.5]  2.618976               1       None  None         None
# 4  [36.7, 24.5]  2.618976               1       None  None         None
#
#   pass_recipient pass_recipient_id pass_length pass_angle pass_height  \
# 0           None              None        None       None        None
# 1           None              None        None       None        None
# 2           None              None        None       None        None
# 3           None              None        None       None        None
# 4           None              None        None       None        None
#
#   pass_end_location pass_body_part pass_type pass_outcome pass_technique  \
# 0              null           None      None         None           None
# 1              null           None      None         None           None
# 2              null           None      None         None           None
# 3              null           None      None         None           None
# 4              null           None      None         None           None
#
#   pass_switch pass_cross pass_assisted_shot_id pass_shot_assist  \
# 0        None       None                  None             None
# 1        None       None                  None             None
# 2        None       None                  None             None
# 3        None       None                  None             None
# 4        None       None                  None             None
#
#   pass_inswinging pass_outswinging pass_cut_back pass_deflected  \
# 0            None             None          None           None
# 1            None             None          None           None
# 2            None             None          None           None
# 3            None             None          None           None
# 4            None             None          None           None
#
#   pass_through_ball carry_end_location shot_end_location shot_statsbomb_xg  \
# 0              None        [37.7, 8.8]              null              None
# 1              None        [37.7, 8.8]              null              None
# 2              None        [37.7, 8.8]              null              None
# 3              None        [37.7, 8.8]              null              None
# 4              None        [37.7, 8.8]              null              None
#
#   shot_outcome shot_type shot_body_part shot_technique shot_first_time  \
# 0         None      None           None           None            None
# 1         None      None           None           None            None
# 2         None      None           None           None            None
# 3         None      None           None           None            None
# 4         None      None           None           None            None
#
#   shot_key_pass_id shot_aerial_won shot_freeze_frame goalkeeper_position  \
# 0             None            None              null                None
# 1             None            None              null                None
# 2             None            None              null                None
# 3             None            None              null                None
# 4             None            None              null                None
#
#   goalkeeper_type goalkeeper_outcome goalkeeper_body_part  \
# 0            None               None                 None
# 1            None               None                 None
# 2            None               None                 None
# 3            None               None                 None
# 4            None               None                 None
#
#   goalkeeper_end_location goalkeeper_technique dribble_outcome  \
# 0                    null                 None            None
# 1                    null                 None            None
# 2                    null                 None            None
# 3                    null                 None            None
# 4                    null                 None            None
#
#   dribble_overrun dribble_nutmeg duel_type duel_outcome 50_50  \
# 0            None           None      None         None  null
# 1            None           None      None         None  null
# 2            None           None      None         None  null
# 3            None           None      None         None  null
# 4            None           None      None         None  null
#
#   block_deflection block_offensive clearance_head clearance_left_foot  \
# 0             None            None           None                None
# 1             None            None           None                None
# 2             None            None           None                None
# 3             None            None           None                None
# 4             None            None           None                None
#
#   clearance_right_foot clearance_body_part clearance_aerial_won  \
# 0                 None                None                 None
# 1                 None                None                 None
# 2                 None                None                 None
# 3                 None                None                 None
# 4                 None                None                 None
#
#   ball_receipt_outcome ball_recovery_recovery_failure ball_recovery_offensive  \
# 0                 None                           None                    None
# 1                 None                           None                    None
# 2                 None                           None                    None
# 3                 None                           None                    None
# 4                 None                           None                    None
#
#   foul_committed_type foul_committed_advantage foul_committed_card  \
# 0                None                     None                None
# 1                None                     None                None
# 2                None                     None                None
# 3                None                     None                None
# 4                None                     None                None
#
#   foul_committed_penalty foul_won_advantage foul_won_defensive  \
# 0                   None               None               None
# 1                   None               None               None
# 2                   None               None               None
# 3                   None               None               None
# 4                   None               None               None
#
#   interception_outcome miscontrol_aerial_won injury_stoppage_in_chain  \
# 0                 None                  None                     None
# 1                 None                  None                     None
# 2                 None                  None                     None
# 3                 None                  None                     None
# 4                 None                  None                     None
#
#   substitution_outcome substitution_outcome_id substitution_replacement  \
# 0                 None                    None                     None
# 1                 None                    None                     None
# 2                 None                    None                     None
# 3                 None                    None                     None
# 4                 None                    None                     None
#
#   substitution_replacement_id  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
#
#                                       related_events  match_id  \
# 0  ["ae18bca7-36a4-4fdd-b7ed-f9f6e8b12911", "833e...   3857267
# 1  ["ae18bca7-36a4-4fdd-b7ed-f9f6e8b12911", "833e...   3857267
# 2  ["ae18bca7-36a4-4fdd-b7ed-f9f6e8b12911", "833e...   3857267
# 3  ["ae18bca7-36a4-4fdd-b7ed-f9f6e8b12911", "833e...   3857267
# 4  ["ae18bca7-36a4-4fdd-b7ed-f9f6e8b12911", "833e...   3857267
#
#           data_valid_from_utc           data_valid_to_utc
# 0  2026-08-04 13:37:45.264843  2026-08-04 13:45:52.575567
# 1  2026-08-04 13:40:29.748350  2026-08-04 13:45:52.575567
# 2  2026-08-04 13:42:49.718446  2026-08-04 13:45:52.575567
# 3  2026-08-04 13:43:18.301228  2026-08-04 13:45:52.575567
# 4  2026-08-04 13:45:52.576567                         NaN

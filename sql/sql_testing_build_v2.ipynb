# %%
import sqlite3
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
connection = sqlite3.connect('../dbs/bronze.db')

# 2. Read query directly into a DataFrame
df = pd.read_sql_query('SELECT * FROM competitions', connection)

# 3. Always close the connection when finished
connection.close()

df
# Out:
#    competition_id  season_id   country_name competition_name  \
# 0              43        106  International   FIFA World Cup
# 1              43        106  International   FIFA World Cup
#
#   competition_gender  competition_youth  competition_international  \
# 0               male                  0                          1
# 1               male                  0                          1
#
#   season_name               match_updated           match_updated_360  \
# 0        2022  2026-05-04 01:48:57.914346  2026-05-04 01:53:40.309717
# 1        2022  2026-05-04 01:48:57.914346  2026-05-04 01:53:40.309717
#
#           match_available_360             match_available  \
# 0  2026-05-04 01:53:40.309717  2026-05-04 01:48:57.914346
# 1  2026-05-04 01:53:40.309717  2026-05-04 01:48:57.914346
#
#           data_valid_from_utc           data_valid_to_utc
# 0  2026-08-03 10:18:47.994552  2026-08-03 10:19:09.731772
# 1  2026-08-03 10:19:09.732772                         NaN
